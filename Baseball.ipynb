# %% [markdown]
# ## Importing Dataset and Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('/content/baseball.csv')

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# ## Null Values

# %% [markdown]
# There are no null values in our dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# ## Visualizations and Descriptions

# %% [markdown]
# The main problem that we have is a very small dataset. We only have 30 instances ! Even if we spot outliers we cannot get rid of them due to 2 major reasons -
#
# 1.) First being this dataset is very small to pinpoint outliers, what might look outliers to us in this dataset might actually be real datapoints when the dataset has more instances.
#
# 2.) Since logically speaking with so much less information we cannot risk losing any more information hence we will retain all the data that we have.

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# Univariate Analysis

# %%
num_histograms = 17
num_cols = 2
num_rows = 9
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(12, 20))

axes = axes.flatten()
for i, col in enumerate(df.columns[:num_histograms]):
    axes[i].hist(df[col], bins=50)
    axes[i].set_title(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# Bivariate Analysis

# %%
num_histograms = 17
num_cols = 2
num_rows = 9
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(12, 20))

axes = axes.flatten()
for i, col in enumerate(df.columns[:num_histograms]):
    axes[i].scatter(df['W'], df[col])
    axes[i].set_title(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# ERA, RA, ER seems to have a negative correlation with number of wins looking at the plot.
#
# Whereas SV, SHO seem to have a positive correlation with the number of wins.

# %% [markdown]
# Multivariate Analysis

# %% [markdown]
# Now from the below plot as well we can look at the density and conclude that indeed ERA, RA, ER not only seem to have a high negative correlation but also the density for the same is more.

# %%
num_histograms = 17
num_cols = 2
num_rows = 9
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(12, 30))

axes = axes.flatten()

reference_hex = axes[0].hexbin(df['W'], df[df.columns[0]], gridsize=20, cmap='inferno', edgecolors='gray')

for i, col in enumerate(df.columns[:num_histograms]):
    axes[i].hexbin(df['W'], df[col], gridsize=20, cmap='inferno', edgecolors='gray')
    axes[i].set_title(col)

colorbar = fig.colorbar(reference_hex, ax=axes.ravel(), orientation='vertical')
colorbar.set_label('Density')

plt.show()

# %% [markdown]
# ## Correlation

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
corr_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# RA, ERA, ER 3 of the columns are have a high correlation with each other as well. As in if the value of one column goes up the value of other column will also go up ! This is what we call multicollinearity problem.

# %% [markdown]
# We will not touch the data for now.

# %% [markdown]
# ## Skewness

# %% [markdown]
# The data doesn't seems to be skewed as much either, let us leave it as it is.

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# ## Splitting the data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop('W', axis=1), df['W'], test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (24, 16)

# %%
X_test.shape
# Out:
# (6, 16)

# %%
y_train.shape
# Out:
# (24,)

# %%
y_test.shape
# Out:
# (6,)

# %% [markdown]
# ## VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif['Features'] = X_train.columns
vif['VIF'] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
vif
# Out:
#    Features           VIF
# 0         R   2080.739078
# 1        AB   4390.370008
# 2         H   4798.912670
# 3        2B    863.480097
# 4        3B     55.426062
# 5        HR    320.795949
# 6        BB    307.405411
# 7        SO    433.533840
# 8        SB     35.078267
# 9        RA  17598.069306
# 10       ER  61169.327424
# 11      ERA  32011.238771
# 12       CG      8.603787
# 13      SHO     38.260273
# 14       SV    158.908834
# 15        E     98.868868

# %%
X_train = X_train.drop(['RA', 'ER'], axis=1)
X_test = X_test.drop(['RA', 'ER'], axis=1)

# %%
vif = pd.DataFrame()
vif['Features'] = X_train.columns
vif['VIF'] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
vif
# Out:
#    Features          VIF
# 0         R  1605.735343
# 1        AB  3779.309478
# 2         H  3998.676590
# 3        2B   817.173067
# 4        3B    54.458846
# 5        HR   256.876063
# 6        BB   276.018999
# 7        SO   350.539681
# 8        SB    30.721219
# 9       ERA   646.138849
# 10       CG     8.255836
# 11      SHO    30.210790
# 12       SV    97.879139
# 13        E    69.031768

# %%
X_train = X_train.drop(['H', 'AB'], axis=1)
X_test = X_test.drop(['H', 'AB'], axis=1)

# %%
vif = pd.DataFrame()
vif['Features'] = X_train.columns
vif['VIF'] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
vif
# Out:
#    Features         VIF
# 0         R  802.468261
# 1        2B  741.881210
# 2        3B   44.622551
# 3        HR  168.183184
# 4        BB  219.636759
# 5        SO  300.090243
# 6        SB   20.372805
# 7       ERA  245.106337
# 8        CG    6.880784
# 9       SHO   16.530240
# 10       SV   67.375830
# 11        E   60.430081

# %% [markdown]
# ## Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## PCA

# %% [markdown]
# Now since our data has more amount features somehow nearly 2/3 of the instances we have. In such scenarious Lasso Regression or l1 regularization is not preferred as it behaves erratically when the number of features are high as compared to the number of instances.
#
# We will discuss about this further when deciding which models will be good in such scenarious.
#
# For now let us use PCA to understand which columns we need to eliminate.

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 12)
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

# %%
explained_variance_ratio_ = pca.explained_variance_ratio_
cumulative_explained_variance = np.cumsum(explained_variance_ratio_)

plt.plot(range(1, len(explained_variance_ratio_) + 1), explained_variance_ratio_, marker='o', linestyle='--')
plt.plot(range(1, len(explained_variance_ratio_) + 1), cumulative_explained_variance, marker='o', linestyle='-')
plt.xlabel('Number of Components')
plt.ylabel('Explained Variance Ratio')
plt.title('Scree Plot')
plt.grid(True)
plt.show()

# %%
pca.explained_variance_ratio_
# Out:
# array([0.27707636, 0.17456807, 0.14400821, 0.1157266 , 0.08011548,
#        0.06627136, 0.04783239, 0.04219176, 0.02238926, 0.01677751,
#        0.00811091, 0.00493208])

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.9999999999999999

# %% [markdown]
# ## Models

# %% [markdown]
# We will be using models like ridge regression as these perform better in such scenarious.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

lr = LinearRegression()
lr.fit(X_train_pca, y_train)

y_pred = lr.predict(X_test_pca)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("R-squared:", r2)
# Out:
# Mean Absolute Error: 3.8365643783371204
# Mean Squared Error: 27.827926556366837
# Root Mean Squared Error: 5.275218152490647
# R-squared: 0.7885148076780227

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_features = PolynomialFeatures(degree=2, include_bias=False)
X_poly_train = poly_features.fit_transform(X_train_pca)
X_poly_test = poly_features.transform(X_test_pca)

poly_reg = LinearRegression()
poly_reg.fit(X_poly_train, y_train)

y_poly_pred = poly_reg.predict(X_poly_test)

mae = mean_absolute_error(y_test, y_poly_pred)
mse = mean_squared_error(y_test, y_poly_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("R-squared:", r2)
# Out:
# Mean Absolute Error: 8.2844329784733
# Mean Squared Error: 102.12924193844674
# Root Mean Squared Error: 10.105901342208261
# R-squared: 0.7885148076780227

# %%
from sklearn.linear_model import SGDRegressor

sgd_reg = SGDRegressor(max_iter=1000, tol=1e-3, penalty=None, eta0=0.1)
sgd_reg.fit(X_train_pca, y_train)

y_pred = sgd_reg.predict(X_test_pca)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("R-squared:", r2)
# Out:
# Mean Absolute Error: 3.7605045072408956
# Mean Squared Error: 27.979899398767415
# Root Mean Squared Error: 5.289602952846973
# R-squared: 0.7873598525742819

# %%
from sklearn.ensemble import RandomForestRegressor

rfr = RandomForestRegressor(n_estimators = 500, max_depth = 20,
                            min_samples_split = 3, random_state=42)
rfr.fit(X_train_pca, y_train)

y_pred = rfr.predict(X_test_pca)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("R-squared:", r2)
# Out:
# Mean Absolute Error: 7.959241269841274
# Mean Squared Error: 69.99130808540443
# Root Mean Squared Error: 8.366080807965247
# R-squared: 0.46808378909129

# %%
from sklearn.tree import DecisionTreeRegressor

tree_reg = DecisionTreeRegressor(max_depth = 4, random_state=42)
tree_reg.fit(X_train_pca, y_train)

y_pred = tree_reg.predict(X_test_pca)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("R-squared:", r2)
# Out:
# Mean Absolute Error: 7.452380952380949
# Mean Squared Error: 76.06916099773235
# Root Mean Squared Error: 8.721763640327131
# R-squared: 0.4218936466290132

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbrt = GradientBoostingRegressor(max_depth = 2, n_estimators = 100, learning_rate = 0.1, random_state=42)
gbrt.fit(X_train_pca, y_train)

y_pred = gbrt.predict(X_test_pca)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("R-squared:", r2)
# Out:
# Mean Absolute Error: 7.054291796920777
# Mean Squared Error: 52.79983520765546
# Root Mean Squared Error: 7.266349510425125
# R-squared: 0.5987346279342207

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge()
ridge_reg.fit(X_train_pca, y_train)

y_pred = ridge_reg.predict(X_test_pca)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("R-squared:", r2)
# Out:
# Mean Absolute Error: 4.301088531554345
# Mean Squared Error: 30.606862283924965
# Root Mean Squared Error: 5.532346905602085
# R-squared: 0.7673956001221662

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The best model in this case is the SGD Regressor Model with an MAE of 3.7605045072408956.
